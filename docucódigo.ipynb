# %% [markdown]
# <a href="https://colab.research.google.com/github/JefersonCardona/Algoritmia-Programacion/blob/main/docuc%C3%B3digo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from datetime import datetime
import logging

# %%
# Definimos la ruta final donde se guardará el archivo de log
RutaFinal = 'Ruta_final'

# Verificamos si la ruta final existe, si no, la creamos
if not os.path.exists(RutaFinal):
    os.makedirs(RutaFinal)

# Creamos la ruta completa del archivo de log
ArchivoLog = os.path.join(RutaFinal, 'asignaciones.log')

# Inicializamos una lista para almacenar los mensajes del log
MensajesLog = []

# Definimos una función para manejar los mensajes de log
def MensajeLog(L, Mensaje):
    # Añadimos el mensaje a la lista con un timestamp y el nivel de log
    MensajesLog.append(f"{datetime.now()} - {L} - {Mensaje}")

    # Imprimimos el mensaje en la consola si el nivel es INFO o ERROR
    if L == "INFO":
        print(f"{datetime.now()} - INFO - {Mensaje}")
    elif L == "ERROR":
        print(f"{datetime.now()} - ERROR - {Mensaje}")

# Registro inicial en el log
MensajeLog("INFO", "Cargando datos de Estudiantes y Malla Curricular")

# Carga de datos de estudiantes desde un archivo CSV remoto
# Se omite la columna 'Fecha' en los datos cargados
Datos = pd.read_csv('https://github.com/JefersonCardona/Algoritmia-Programacion/raw/eb776f421bb990b8c16ded477572f5d436f1f646/Archivos/Estudiantes.csv', encoding='latin1', delimiter=';').drop(columns=['Fecha'])

# Carga de la malla curricular desde un archivo CSV remoto
MallaCurricular = pd.read_csv('https://github.com/JefersonCardona/Algoritmia-Programacion/raw/eb776f421bb990b8c16ded477572f5d436f1f646/Archivos/MallaCurricular.csv',encoding='latin1',delimiter=';')

# Registro en el log después de cargar los datos
MensajeLog("INFO", "Datos cargados con éxito")

def AsignaturaCode(asignatura, semestre, creditos, consecutivo):
    """
    Crea un código para una asignatura con información básica.

    Parámetros:
    - asignatura: El nombre de la asignatura.
    - semestre: En qué semestre se da la asignatura.
    - creditos: Cuántos créditos vale la asignatura.
    - consecutivo: Un número para diferenciar asignaturas similares.

    Retorna:
    - Un código como texto que combina la información dada.
    """
    # Combina las primeras tres letras de la asignatura en mayúsculas,
    # el número del semestre, los créditos y un número consecutivo.
    return f"{asignatura[:3].upper()}{semestre}{creditos}{consecutivo:02d}"

def HTD(creditos):
    """
    Calcula las Horas de Trabajo del Docente (HTD) basadas en los créditos de una asignatura.

    Parámetros:
    - creditos: Número de créditos de la asignatura.

    Devuelve:
    - El número de horas de trabajo del docente correspondiente a los créditos.
    """
    # Se retorna un valor fijo de horas dependiendo del número de créditos.
    if creditos == 4:
        return 96
    elif creditos == 3:
        return 64
    elif creditos == 2:
        return 32
    elif creditos == 1:
        return 16
    # Si no coincide con ningún caso anterior, se retorna 0.
    return 0

def HTI(creditos):
    """
    Calcula las Horas de Trabajo Independiente (HTI) basadas en los créditos de una asignatura.

    Parámetros:
    - creditos: Número de créditos de la asignatura.

    Devuelve:
    - El número de horas de trabajo independiente correspondiente a los créditos.
    """
    # Se retorna un valor fijo de horas dependiendo del número de créditos.
    if creditos == 4:
        return 120
    elif creditos == 3:
        return 80
    elif creditos == 2:
        return 64
    elif creditos == 1:
        return 32
    # Si no coincide con ningún caso anterior, se retorna 0.
    return 0

    # Definimos la función principal que se encargará de matricular estudiantes.
def FuncionPrincipal(estudiantes_df, asignaturas_df, semestre, nivel, tamano_grupo):
    # Registramos un mensaje en el log para indicar el inicio del proceso de matriculación.
    MensajeLog("INFO", f"Matriculando estudiantes para el semestre {semestre}, nivel {nivel}")

    # Filtramos los estudiantes que corresponden al semestre actual.
    estudiantes_semestre = estudiantes_df[estudiantes_df['Semestre'] == semestre]

    # Contamos el total de estudiantes para este semestre.
    total_estudiantes_semestre = len(estudiantes_semestre)

    # Filtramos las asignaturas que corresponden al nivel actual.
    asignaturas_nivel = asignaturas_df[asignaturas_df['Nivel'] == nivel]

    # Creamos grupos de estudiantes con el tamaño especificado.
    grupos = [estudiantes_semestre[i:i + tamano_grupo] for i in range(0, len(estudiantes_semestre), tamano_grupo)]

    # Preparamos el directorio donde se guardarán las asignaciones.
    Directorio = os.path.join(RutaFinal, f'Asignaciones_Semestre_{semestre}')

    # Si el directorio no existe, lo creamos.
    if not os.path.exists(Directorio):
        os.makedirs(Directorio)
        MensajeLog("INFO", f"Directorio creado: {Directorio}")

    # Iteramos sobre cada asignatura del nivel actual.
    for index, asignatura in asignaturas_nivel.iterrows():
        # Obtenemos el nombre y los créditos de la asignatura.
        asignatura_nombre = asignatura['Asignatura']
        creditos = asignatura['Creditos']

        # Calculamos el total de cursos asignados.
        total_cursos_asignados = len(grupos)

        # Obtenemos la fecha actual en formato de año, mes y día.
        fecha_creacion = datetime.now().strftime('%Y%m%d')

        # Preparamos el directorio para la asignatura actual.
        asignatura_dir = os.path.join(Directorio, asignatura_nombre)

        # Si el directorio de la asignatura no existe, lo creamos.
        if not os.path.exists(asignatura_dir):
            os.makedirs(asignatura_dir)
            MensajeLog("INFO", f"Directorio creado: {asignatura_dir}")

        # Iteramos sobre cada grupo de estudiantes.
        for numero_grupo, grupo in enumerate(grupos, start=1):
            # Generamos el código de la asignatura.
            codigo_asignatura = AsignaturaCode(asignatura_nombre, semestre, creditos, numero_grupo)

            # Calculamos las horas de trabajo docente e independiente basadas en los créditos.
            horas_trabajo_docente = HTD(creditos)
            horas_trabajo_independiente = HTI(creditos)

            # Establecemos el número total de estudiantes y la cantidad de estudiantes en el grupo actual.
            numero_total_estudiantes = total_estudiantes_semestre
            cantidad_estudiantes = len(grupo)

            # Formateamos el nombre de la asignatura para el nombre del archivo.
            nombre_curso_formateado = asignatura_nombre.replace(" ", "").capitalize()

            # Preparamos los nombres de los archivos CSV y Excel para el grupo actual.
            grupo_filename = f"{codigo_asignatura}-{nombre_curso_formateado}-{cantidad_estudiantes}-{numero_grupo}.csv"
            grupo_excel_filename = f"{codigo_asignatura}-{nombre_curso_formateado}-{cantidad_estudiantes}-{numero_grupo}.xlsx"

            # Establecemos las rutas completas para los archivos del grupo.
            grupo_path = os.path.join(asignatura_dir, grupo_filename)
            grupo_excel_path = os.path.join(asignatura_dir, grupo_excel_filename)

            # Creamos un DataFrame con la información del grupo y lo guardamos en los archivos correspondientes.
            grupo_df = pd.DataFrame({'Estudiante': grupo['Nombre'], '(CA)': codigo_asignatura, '(HTD)': horas_trabajo_docente, '(HTI)': horas_trabajo_independiente, '(NTE)': numero_total_estudiantes, '(CC)': numero_grupo, '(TCA)': total_cursos_asignados, '(FC)': fecha_creacion })
            grupo_df.to_csv(grupo_path, index=False, encoding='latin1')
            grupo_df.to_excel(grupo_excel_path, index=False)

            # Registramos un mensaje en el log para cada grupo generado.
            MensajeLog("INFO", f"Archivos generados para la asignatura {asignatura_nombre}, grupo {numero_grupo}")

    # Registramos un mensaje final en el log para indicar que se han generado todos los archivos CSV.
    MensajeLog("INFO", f"Archivos CSV de asignaciones generados para el semestre {semestre}")
# Out:
# 2024-06-07 03:42:42.538705 - INFO - Cargando datos de Estudiantes y Malla Curricular
# 2024-06-07 03:42:43.290764 - INFO - Datos cargados con éxito

# %%
# Aquí estamos llamando a la función 'FuncionPrincipal' varias veces con diferentes parámetros.
# Cada llamada corresponde a un semestre y nivel específico, con un tamaño de grupo determinado.

# Matriculamos estudiantes de primer semestre de nivel 1 en grupos de 30.
FuncionPrincipal(Datos, MallaCurricular, semestre=1, nivel=1, tamano_grupo=30)

# Matriculamos estudiantes de segundo semestre de nivel 2 en grupos de 30.
FuncionPrincipal(Datos, MallaCurricular, semestre=2, nivel=2, tamano_grupo=30)

# Continuamos este proceso hasta el décimo semestre, ajustando el tamaño del grupo según sea necesario.
FuncionPrincipal(Datos, MallaCurricular, semestre=3, nivel=3, tamano_grupo=30)
FuncionPrincipal(Datos, MallaCurricular, semestre=4, nivel=4, tamano_grupo=25)
FuncionPrincipal(Datos, MallaCurricular, semestre=5, nivel=5, tamano_grupo=25)
FuncionPrincipal(Datos, MallaCurricular, semestre=6, nivel=6, tamano_grupo=25)
FuncionPrincipal(Datos, MallaCurricular, semestre=7, nivel=7, tamano_grupo=20)
FuncionPrincipal(Datos, MallaCurricular, semestre=8, nivel=8, tamano_grupo=20)
FuncionPrincipal(Datos, MallaCurricular, semestre=9, nivel=9, tamano_grupo=20)
FuncionPrincipal(Datos, MallaCurricular, semestre=10, nivel=10, tamano_grupo=10)

# Después de matricular a los estudiantes, procedemos a escribir los mensajes de registro.
# Abrimos el archivo de registro en modo de escritura.
with open(ArchivoLog, 'w') as log_file:
    # Iteramos sobre cada mensaje en la lista de mensajes de registro.
    for Mensaje in MensajesLog:
        # Escribimos cada mensaje en el archivo de registro seguido de un salto de línea.
        log_file.write(Mensaje + '\n')
# Out:
# 2024-06-07 03:42:51.549310 - INFO - Matriculando estudiantes para el semestre 1, nivel 1
# 2024-06-07 03:42:51.552598 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_1
# 2024-06-07 03:42:51.553218 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_1/
- INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_4/Electiva en Fisica
# 2024-06-07 03:42:53.561734 - INFO - Archivos generados para la asignatura Electiva en Fisica, grupo 1
# 2024-06-07 03:42:53.576893 - INFO - Archivos generados para la asignatura Electiva en Fisica, grupo 2
# 2024-06-07 03:42:53.595714 - INFO - Archivos generados para la asignatura Electiva en Fisica, grupo 3
# 2024-06-07 03:42:53.612073 - INFO - Archivos generados para la asignatura Electiva en Fisica, grupo 4
# 2024-06-07 03:42:53.626309 - INFO - Archivos generados para la asignatura Electiva en Fisica, grupo 5
# 2024-06-07 03:42:53.627445 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_4/Ingles IV
# 2024-06-07 03:42:53.642911 - INFO - Archivos generados para la asignatura Ingles IV, grupo 1
# 2024-06-07 03:42:53.659328 - INFO - Archivos generados para la asignatura Ingles IV, grupo 2
# 2024-06-07 03:42:53.674412 - INFO - Archivos generados para la asignatura Ingles IV, grupo 3
# 2024-06-07 03:42:53.689358 - INFO - Archivos generados para la asignatura Ingles IV, grupo 4
# 2024-06-07 03:42:53.701840 - INFO - Archivos generados para la asignatura Ingles IV, grupo 5
# 2024-06-07 03:42:53.702965 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_4/Diseno de Experimentos y Analisis de Regresion
# 2024-06-07 03:42:53.717635 - INFO - Archivos generados para la asignatura Diseno de Experimentos y Analisis de Regresion, grupo 1
# 2024-06-07 03:42:53.732627 - INFO - Archivos generados para la asignatura Diseno de Experimentos y Analisis de Regresion, grupo 2
# 2024-06-07 03:42:53.747246 - INFO - Archivos generados para la asignatura Diseno de Experimentos y Analisis de Regresion, grupo 3
# 2024-06-07 03:42:53.762861 - INFO - Archivos generados para la asignatura Diseno de Experimentos y Analisis de Regresion, grupo 4
# 2024-06-07 03:42:53.775907 - INFO - Archivos generados para la asignatura Diseno de Experimentos y Analisis de Regresion, grupo 5
# 2024-06-07 03:42:53.777419 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_4/Optimizacion
# 2024-06-07 03:42:53.795721 - INFO - Archivos generados para la asignatura Optimizacion, grupo 1
# 2024-06-07 03:42:53.814632 - INFO - Archivos generados para la asignatura Optimizacion, grupo 2
# 2024-06-07 03:42:53.830209 - INFO - Archivos generados para la asignatura Optimizacion, grupo 3
# 2024-06-07 03:42:53.848656 - INFO - Archivos generados para la asignatura Optimizacion, grupo 4
# 2024-06-07 03:42:53.860906 - INFO - Archivos generados para la asignatura Optimizacion, grupo 5
# 2024-06-07 03:42:53.862197 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_4/Gestion de Metodos y Tiempos
# 2024-06-07 03:42:53.877404 - INFO - Archivos generados para la asignatura Gestion de Metodos y Tiempos, grupo 1
# 2024-06-07 03:42:53.893670 - INFO - Archivos generados para la asignatura Gestion de Metodos y Tiempos, grupo 2
# 2024-06-07 03:42:53.909672 - INFO - Archivos generados para la asignatura Gestion de Metodos y Tiempos, grupo 3
# 2024-06-07 03:42:53.927758 - INFO - Archivos generados para la asignatura Gestion de Metodos y Tiempos, grupo 4
# 2024-06-07 03:42:53.940334 - INFO - Archivos generados para la asignatura Gestion de Metodos y Tiempos, grupo 5
# 2024-06-07 03:42:53.940442 - INFO - Archivos CSV de asignaciones generados para el semestre 4
# 2024-06-07 03:42:53.940799 - INFO - Matriculando estudiantes para el semestre 5, nivel 5
# 2024-06-07 03:42:53.943932 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5
# 2024-06-07 03:42:53.944994 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Gestion Financiera
# 2024-06-07 03:42:53.963125 - INFO - Archivos generados para la asignatura Gestion Financiera, grupo 1
# 2024-06-07 03:42:53.988000 - INFO - Archivos generados para la asignatura Gestion Financiera, grupo 2
# 2024-06-07 03:42:54.006862 - INFO - Archivos generados para la asignatura Gestion Financiera, grupo 3
# 2024-06-07 03:42:54.025787 - INFO - Archivos generados para la asignatura Gestion Financiera, grupo 4
# 2024-06-07 03:42:54.027190 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Laboratorio Integrado de Fisica
# 2024-06-07 03:42:54.042848 - INFO - Archivos generados para la asignatura Laboratorio Integrado de Fisica, grupo 1
# 2024-06-07 03:42:54.058355 - INFO - Archivos generados para la asignatura Laboratorio Integrado de Fisica, grupo 2
# 2024-06-07 03:42:54.073496 - INFO - Archivos generados para la asignatura Laboratorio Integrado de Fisica, grupo 3
# 2024-06-07 03:42:54.092153 - INFO - Archivos generados para la asignatura Laboratorio Integrado de Fisica, grupo 4
# 2024-06-07 03:42:54.093408 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Ingles V
# 2024-06-07 03:42:54.108491 - INFO - Archivos generados para la asignatura Ingles V, grupo 1
# 2024-06-07 03:42:54.123935 - INFO - Archivos generados para la asignatura Ingles V, grupo 2
# 2024-06-07 03:42:54.139760 - INFO - Archivos generados para la asignatura Ingles V, grupo 3
# 2024-06-07 03:42:54.154786 - INFO - Archivos generados para la asignatura Ingles V, grupo 4
# 2024-06-07 03:42:54.155972 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Formacion Ciudadana y Constitucional
# 2024-06-07 03:42:54.170768 - INFO - Archivos generados para la asignatura Formacion Ciudadana y Constitucional, grupo 1
# 2024-06-07 03:42:54.186210 - INFO - Archivos generados para la asignatura Formacion Ciudadana y Constitucional, grupo 2
# 2024-06-07 03:42:54.202594 - INFO - Archivos generados para la asignatura Formacion Ciudadana y Constitucional, grupo 3
# 2024-06-07 03:42:54.217643 - INFO - Archivos generados para la asignatura Formacion Ciudadana y Constitucional, grupo 4
# 2024-06-07 03:42:54.218853 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Dinamica de Sistemas
# 2024-06-07 03:42:54.238996 - INFO - Archivos generados para la asignatura Dinamica de Sistemas, grupo 1
# 2024-06-07 03:42:54.263496 - INFO - Archivos generados para la asignatura Dinamica de Sistemas, grupo 2
# 2024-06-07 03:42:54.287813 - INFO - Archivos generados para la asignatura Dinamica de Sistemas, grupo 3
# 2024-06-07 03:42:54.314908 - INFO - Archivos generados para la asignatura Dinamica de Sistemas, grupo 4
# 2024-06-07 03:42:54.316327 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Muestreo y Series de Tiempo
# 2024-06-07 03:42:54.342494 - INFO - Archivos generados para la asignatura Muestreo y Series de Tiempo, grupo 1
# 2024-06-07 03:42:54.365809 - INFO - Archivos generados para la asignatura Muestreo y Series de Tiempo, grupo 2
# 2024-06-07 03:42:54.389565 - INFO - Archivos generados para la asignatura Muestreo y Series de Tiempo, grupo 3
# 2024-06-07 03:42:54.411345 - INFO - Archivos generados para la asignatura Muestreo y Series de Tiempo, grupo 4
# 2024-06-07 03:42:54.412815 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Procesos Estocasticos y Analisis de Decision
# 2024-06-07 03:42:54.436968 - INFO - Archivos generados para la asignatura Procesos Estocasticos y Analisis de Decision, grupo 1
# 2024-06-07 03:42:54.464052 - INFO - Archivos generados para la asignatura Procesos Estocasticos y Analisis de Decision, grupo 2
# 2024-06-07 03:42:54.489763 - INFO - Archivos generados para la asignatura Procesos Estocasticos y Analisis de Decision, grupo 3
# 2024-06-07 03:42:54.509993 - INFO - Archivos generados para la asignatura Procesos Estocasticos y Analisis de Decision, grupo 4
# 2024-06-07 03:42:54.511298 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_5/Gestion por Procesos
# 2024-06-07 03:42:54.533257 - INFO - Archivos generados para la asignatura Gestion por Procesos, grupo 1
# 2024-06-07 03:42:54.555855 - INFO - Archivos generados para la asignatura Gestion por Procesos, grupo 2
# 2024-06-07 03:42:54.580655 - INFO - Archivos generados para la asignatura Gestion por Procesos, grupo 3
# 2024-06-07 03:42:54.605106 - INFO - Archivos generados para la asignatura Gestion por Procesos, grupo 4
# 2024-06-07 03:42:54.605241 - INFO - Archivos CSV de asignaciones generados para el semestre 5
# 2024-06-07 03:42:54.605819 - INFO - Matriculando estudiantes para el semestre 6, nivel 6
# 2024-06-07 03:42:54.610214 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_6
# 2024-06-07 03:42:54.611667 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_6/Gestion Tecnologica
# 2024-06-07 03:42:54.637204 - INFO - Archivos generados para la asignatura Gestion Tecnologica, grupo 1
# 2024-06-07 03:42:54.665099 - INFO - Archivos generados para la asignatura Gestion Tecnologica, grupo 2
# 2024-06-07 03:42:54.693568 - INFO - Archivos generados para la asignatura Gestion Tecnologica, grupo 3
# 2024-06-07 03:42:54.718821 - INFO - Archivos generados para la asignatura Gestion Tecnologica, grupo 4
# 2024-06-07 03:42:54.738780 - INFO - Archivos generados para la asignatura Gestion Tecnologica, grupo 5
# 2024-06-07 03:42:54.740200 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_6/Legislacion
# 2024-06-07 03:42:54.764779 - INFO - Archivos generados para la asignatura Legislacion, grupo 1
# 2024-06-07 03:42:54.788120 - INFO - Archivos generados para la asignatura Legislacion, grupo 2
# 2024-06-07 03:42:54.811233 - INFO - Archivos generados para la asignatura Legislacion, grupo 3
# 2024-06-07 03:42:54.834624 - INFO - Archivos generados para la asignatura Legislacion, grupo 4
# 2024-06-07 03:42:54.853056 - INFO - Archivos generados para la asignatura Legislacion, grupo 5
# 2024-06-07 03:42:54.854427 - INFO - Directorio creado: Ruta_final/Asignaciones_Semestre_6/